# %%
# Steve Mitchell
# June 2017

import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import argparse
import cv2
import imutils
import time

# preliminary attempt at lane following system
# largely derived from: https://medium.com/pharos-production/
# road-lane-recognition-with-opencv-and-ios-a892a3ab635c

# identify filename of video to be analyzed
cap = cv2.VideoCapture('Easy_Test.mp4')
i=0

# loop through until entire video file is played
while(cap.isOpened()):

    # read video frame & show on screen
    ret, frame = cap.read()
    i=i+1
    
    if ret==False:
        break
    
    
    # cv2.imshow("Original Scene", frame)
    
   
    
    
    
    
    

    # snip section of video frame of interest & show on screen
    snip = frame[500:720,300:900]
    
    
    
    
    
    
    
    cv2.imshow("Snip",snip)

    # create polygon (trapezoid) mask to select region of interest
    mask = np.zeros((snip.shape[0], snip.shape[1]), dtype="uint8")
    pts = np.array([[0,220],[50,50],[450,50],[600,220]],dtype=np.int32)
    cv2.fillConvexPoly(mask, pts, 255)
    cv2.imshow("Mask", mask)

    # apply mask and show masked image on screen
    masked = cv2.bitwise_and(snip, snip, mask=mask)
    cv2.imshow("Region of Interest", masked)

    # convert to grayscale then black/white to binary image
    frame = cv2.cvtColor(masked, cv2.COLOR_BGR2GRAY)
    thresh = 240
    frame = cv2.threshold(frame, thresh, 255, cv2.THRESH_BINARY)[1]
    cv2.imshow("Black/White", frame)

    # blur image to help with edge detection
    blurred = cv2.GaussianBlur(frame, (11, 11), 0)
    # cv2.imshow("Blurred", blurred)

    # identify edges & show on screen
    edged = cv2.Canny(blurred, 50, 150)
    cv2.imshow("Edged", edged)

    # perform full Hough Transform to identify lane lines
    lines = cv2.HoughLines(edged, 1, np.pi / 180, 25)

    # define arrays for left and right lanes
    rho_left = []
    theta_left = []
    rho_right = []
    theta_right = []

    # ensure cv2.HoughLines found at least one line
    if lines is not None:
 
        # loop through all of the lines found by cv2.HoughLines
        for i in range(0, len(lines)):

            # evaluate each row of cv2.HoughLines output 'lines'
            for rho, theta in lines[i]:

                # collect left lanes
                if theta < np.pi/2 and theta > np.pi/4:
                    rho_left.append(rho)
                    theta_left.append(theta)

                    # # plot all lane lines for DEMO PURPOSES ONLY
                    # a = np.cos(theta); b = np.sin(theta)
                    # x0 = a * rho; y0 = b * rho
                    # x1 = int(x0 + 400 * (-b)); y1 = int(y0 + 400 * (a))
                    # x2 = int(x0 - 600 * (-b)); y2 = int(y0 - 600 * (a))
                    #
                    # cv2.line(snip, (x1, y1), (x2, y2), (0, 0, 255), 1)

                # collect right lanes
                if theta > np.pi/2 and theta < 3*np.pi/4:
                    rho_right.append(rho)
                    theta_right.append(theta)

                    # # plot all lane lines for DEMO PURPOSES ONLY
                    # a = np.cos(theta); b = np.sin(theta)
                    # x0 = a * rho; y0 = b * rho
                    # x1 = int(x0 + 400 * (-b)); y1 = int(y0 + 400 * (a))
                    
                    # x2 = int(x0 - 600 * (-b)); y2 = int(y0 - 600 * (a))
                    #
                    # cv2.line(snip, (x1, y1), (x2, y2), (0, 0, 255), 1)

    # statistics to identify median lane dimensions
    left_rho = np.median(rho_left)
    left_theta = np.median(theta_left)
    right_rho = np.median(rho_right)
    right_theta = np.median(theta_right)

    # plot median lane on top of scene snip
    if left_theta > np.pi/4:
        a = np.cos(left_theta); b = np.sin(left_theta)
        x0 = a * left_rho; y0 = b * left_rho
        offset1 = 150; offset2 = 200
        x1 = int(x0 - offset1 * (-b)); y1 = int(y0 - offset1 * (a))
        x2 = int(x0 + offset2 * (-b)); y2 = int(y0 + offset2 * (a))

        cv2.line(snip, (x1, y1), (x2, y2), (0, 255, 0), 3)
        

    if right_theta > np.pi/4:
        a = np.cos(right_theta); b = np.sin(right_theta)
        x0 = a * right_rho; y0 = b * right_rho
        offset1 = 350; offset2 = 800
        x3 = int(x0 - offset1 * (-b)); y3 = int(y0 - offset1 * (a))
        x4 = int(x0 - offset2 * (-b)); y4 = int(y0 - offset2 * (a))
        

        cv2.line(snip, (x3, y3), (x4, y4), (255, 0, 0), 3)
        
    list =[(x1,y1),(x2,y2),(x3,y3),(x4,y4)]
    print(list)
    
    
    
    
            
    



    # overlay semi-transparent lane outline on original
    if left_theta > np.pi/4 and right_theta > np.pi/4:
        pts = np.array([[x1,y1], [x2, y2], [x4, y4], [x3,y3]], dtype=np.int32)
        

        # (1) create a copy of the original:
        overlay = snip.copy()
        # (2) draw shapes:
        cv2.fillConvexPoly(overlay, pts, (255, 255, 0))
        cv2.imshow('overlay',overlay)
        # (3) blend with the original:
        opacity = 0.4
        cv2.addWeighted(overlay, opacity, snip, 1 - opacity, 0, snip)

    cv2.imshow("Lined", snip)
    x1_=int ((x1+x3)/2)
    y1_=int ((y1+y3)/2)
    
    x2_=int ((x2+x4)/2)
    y2_=int ((y2+y4)/2)
    
    cv2.line( snip ,(x1_,y1_),(x2_,y2_),(255,255,255),2)
    
    cv2.imshow('deviation',snip)
    
    deviation =np.sqrt(np.square(x1_ - (snip.shape[1]/2)) + np.square (y1_ - (snip.shape[0]/2)))
    print(deviation)
    
    

    # perform probablistic Hough Transform to identify lane lines
    # lines = cv2.HoughLinesP(edged, 1, np.pi / 180, 20, 2, 1)
    # for x in range(0, len(lines)):
    #     for x1, y1, x2, y2 in lines[x]:
    #         cv2.line(snip, (x1, y1), (x2, y2), (0, 0, 255), 2)


    # press the q key to break out of video
    if cv2.waitKey(25) & 0xFF == ord('q'):
        break 

# clear everything once finished
cap.release()

cv2.destroyAllWindows()
# Out:
# [(232, 86), (-62, 274), (395, 75), (737, 368)]
# 32.69556544854363
# [(231, 93), (-68, 273), (395, 73), (740, 362)]
# 29.966648127543394
# [(231, 93), (-68, 273), (395, 75), (737, 368)]
# 29.068883707497267
# [(230, 92), (-69, 272), (395, 78), (734, 373)]
# 27.730849247724095
# [(233, 83), (-60, 274), (392, 74), (739, 360)]
# 34.17601498127012
# [(233, 84), (-59, 274), (393, 73), (740, 359)]
# 34.539832078341085
# [(232, 88), (-64, 273), (388, 71), (743, 348)]
# 32.57299494980466
# [(231, 93), (-68, 274), (396, 72), (740, 361)]
# 30.870698080866262
# [(232, 89), (-64, 274), (396, 74), (738, 367)]
# 32.202484376209235
# [(231, 88), (-64, 273), (396, 71), (741, 361)]
# 33.61547262794322
# [(236, 85), (-55, 278), (393, 72), (741, 358)]
# 34.92849839314596
# [(225, 91), (-77, 266), (394, 69), (743, 352)]
# 31.32091952673165
# [(225, 91), (-77, 266), (392, 71), (742, 354)]
# 30.083217912982647
# [(228, 89), (-71, 269), (393, 70), (743, 353)]
# 32.57299494980466
# [(228, 92), (-73, 269), (394, 72), (741, 358)]
# 30.083217912982647
# [(233, 90), (-63, 275), (395, 73), (740, 362)]
# 32.202484376209235
# [(230, 91), (-69, 271), (392, 71), (742, 354)]
# 31.016124838541646
# [(233, 90), (-63, 275), (394, 69), (743, 352)]
# 33.61547262794322
# [(230, 92), (-69, 272), (392, 66), (746, 343)]
# 32.89376840679705
# [(231, 90), (-67, 273), (390, 73), (740, 356)]
# 30.675723300355934
# [(231, 90), (-67, 273), (390, 73), (740, 356)]
# 30.675723300355934
# [(230, 91), (-69, 271), (392, 71), (742, 354)]
# 31.016124838541646
# [(229, 93), (-72, 271), (390, 68), (745, 345)]
# 31.32091952673165
# [(234, 85), (-59, 275), (393, 75), (738, 364)]
# 32.69556544854363
# [(227, 94), (-75, 269), (389, 69), (744, 346)]
# 30.083217912982647
# [(228, 93), (-72, 270), (390, 71), (742, 351)]
# 29.410882339705484
# [(227, 94), (-75, 269), (387, 72), (742, 349)]
# 27.892651361962706
# [(227, 94), (-75, 269), (390, 71), (742, 351)]
# 29.120439557122072
# [(230, 89), (-67, 272), (390, 68), (745, 345)]
# 33.52610922848042
# [(230, 92), (-69, 272), (391, 72), (741, 355)]
# 29.732137494637012
# [(232, 89), (-64, 274), (390, 71), (742, 351)]
# 31.953090617340916
# [(231, 93), (-68, 274), (390, 74), (740, 357)]
# 28.792360097775937
# [(229, 103), (-76, 273), (392, 71), (742, 354)]
# 25.079872407968907
# [(232, 92), (-66, 275), (390, 71), (742, 351)]
# 31.016124838541646
# [(232, 88), (-64, 273), (388, 70), (743, 347)]
# 32.57299494980466
# [(236, 88), (-57, 279), (387, 72), (741, 349)]
# 31.953090617340916
# [(236, 88), (-57, 279), (388, 71), (743, 348)]
# 33.24154027718932
# [(236, 88), (-57, 279), (389, 72), (741, 352)]
# 32.31098884280702
# [(235, 87), (-57, 278), (388, 71), (743, 348)]
# 32.89376840679705
# [(233, 90), (-63, 275), (389, 72), (741, 352)]
# 31.016124838541646
# [(233, 90), (-63, 275), (389, 73), (741, 353)]
# 31.016124838541646
# [(235, 86), (-58, 277), (389, 69), (744, 346)]
# 35.11409973215888
# [(234, 85), (-59, 276), (386, 71), (743, 344)]
# 33.52610922848042
# [(233, 84), (-59, 274), (386, 74), (740, 351)]
# 32.28002478313795
# [(232, 89), (-64, 274), (384, 70), (744, 341)]
# 32.01562118716424
# [(235, 84), (-56, 277), (384, 70), (744, 341)]
# 34.20526275297414
# [(233, 84), (-59, 274), (385, 75), (739, 352)]
# 32.28002478313795
# [(232, 88), (-64, 273), (388, 73), (740, 354)]
# 31.622776601683793
# [(232, 82), (-60, 273), (383, 72), (743, 343)]
# 33.734255586866
# [(230, 85), (-66, 270), (384, 74), (741, 348)]
# 31.78049716414141
# [(226, 93), (-76, 268), (384, 76), (739, 353)]
# 26.476404589747453
# [(227, 96), (-77, 269), (386, 74), (740, 351)]
# 25.709920264364882
# [(231, 90), (-67, 272), (385, 74), (740, 351)]
# 29.120439557122072
# [(233, 83), (-60, 274), (386, 74), (740, 351)]
# 33.24154027718932
# [(233, 83), (-60, 274), (386, 74), (740, 351)]
# 33.24154027718932
# [(233, 84), (-59, 274), (384, 76), (738, 353)]
# 31.04834939252005
# [(229, 94), (-72, 271), (380, 76), (740, 347)]
# 25.317977802344327
# [(230, 95), (-71, 272), (382, 74), (741, 344)]
# 26.68332812825267
# [(229, 97), (-73, 272), (384, 76), (738, 353)]
# 24.73863375370596
# [(229, 97), (-73, 272), (383, 72), (743, 343)]
# 26.68332812825267
# [(229, 97), (-73, 272), (374, 77), (741, 338)]
# 23.021728866442675
# [(234, 86), (-58, 276), (375, 73), (744, 331)]
# 31.25699921617557
# [(226, 86), (-73, 266), (374, 77), (741, 338)]
# 29.0
# [(225, 87), (-75, 265), (374, 77), (741, 338)]
# 28.0178514522438
# [(228, 85), (-70, 268), (378, 79), (737, 350)]
# 28.160255680657446
# [(226, 89), (-74, 267), (376, 76), (740, 341)]
# 28.0178514522438
# [(227, 87), (-72, 267), (377, 75), (741, 339)]
# 29.068883707497267
# [(231, 83), (-63, 271), (373, 81), (737, 346)]
# 28.071337695236398
# [(229, 84), (-67, 270), (372, 77), (741, 335)]
# 30.0
# [(231, 83), (-64, 271), (372, 82), (736, 346)]
# 28.0178514522438
# [(230, 85), (-66, 270), (375, 79), (739, 343)]
# 28.071337695236398
# [(229, 83), (-67, 269), (378, 74), (742, 339)]
# 32.14031735997639
# [(225, 89), (-77, 264), (375, 78), (739, 343)]
# 27.0
# [(226, 86), (-73, 266), (376, 77), (740, 342)]
# 29.017236257093817
# [(223, 94), (-82, 264), (373, 81), (737, 346)]
# 23.08679276123039
# [(223, 93), (-82, 263), (375, 78), (739, 343)]
# 25.019992006393608
# [(225, 90), (-77, 265), (377, 75), (741, 340)]
# 28.0178514522438
# [(227, 86), (-72, 267), (374, 79), (738, 344)]
# 28.0
# [(227, 87), (-72, 268), (375, 78), (739, 342)]
# 28.0178514522438
# [(225, 94), (-78, 266), (373, 81), (737, 345)]
# 23.021728866442675
# [(227, 87), (-72, 267), (375, 78), (739, 343)]
# 28.0178514522438
# [(225, 97), (-80, 267), (371, 81), (738, 342)]
# 21.095023109728988
# [(226, 91), (-76, 266), (376, 77), (740, 342)]
# 26.019223662515376
# [(228, 82), (-68, 267), (375, 80), (737, 348)]
# 29.017236257093817
# [(228, 82), (-68, 267), (371, 79), (740, 337)]
# 30.01666203960727
# [(228, 83), (-67, 268), (374, 80), (738, 344)]
# 29.017236257093817
# [(224, 85), (-76, 263), (373, 81), (737, 346)]
# 27.073972741361768
# [(225, 78), (-71, 263), (373, 81), (737, 345)]
# 31.016124838541646
# [(224, 83), (-75, 263), (375, 80), (737, 348)]
# 29.017236257093817
# [(225, 81), (-72, 264), (376, 82), (735, 352)]
# 29.0
# [(225, 81), (-72, 263), (374, 84), (733, 355)]
# 28.0178514522438
# [(223, 81), (-76, 261), (376, 81), (736, 352)]
# 29.017236257093817
# [(225, 78), (-71, 263), (374, 84), (734, 354)]
# 29.017236257093817
# [(224, 79), (-73, 262), (375, 82), (735, 353)]
# 30.01666203960727
# [(224, 82), (-75, 262), (375, 83), (734, 354)]
# 28.0178514522438
# [(223, 83), (-78, 261), (375, 82), (735, 353)]
# 28.0178514522438
# [(224, 82), (-75, 262), (377, 81), (736, 352)]
# 29.0
# [(224, 82), (-75, 262), (377, 80), (737, 351)]
# 29.0
# [(221, 86), (-83, 259), (376, 77), (740, 341)]
# 29.068883707497267
# [(221, 84), (-81, 259), (377, 81), (736, 352)]
# 28.0178514522438
# [(220, 84), (-84, 257), (378, 83), (733, 360)]
# 27.018512172212592
# [(219, 93), (-89, 257), (375, 81), (736, 349)]
# 23.194827009486403
# [(222, 85), (-80, 260), (378, 78), (738, 349)]
# 29.0
# [(222, 86), (-80, 261), (376, 81), (736, 352)]
# 27.018512172212592
# [(223, 80), (-76, 260), (377, 80), (736, 351)]
# 30.0
# [(222, 84), (-80, 259), (384, 76), (738, 353)]
# 30.14962686336267
# [(224, 88), (-78, 263), (382, 79), (736, 356)]
# 27.16615541441225
# [(224, 88), (-78, 263), (376, 77), (740, 341)]
# 28.0
# [(224, 88), (-78, 263), (380, 76), (740, 347)]
# 28.071337695236398
# [(215, 89), (-94, 251), (381, 78), (738, 352)]
# 27.073972741361768
# [(215, 89), (-94, 251), (375, 78), (739, 342)]
# 27.459060435491963
# [(224, 79), (-73, 262), (377, 80), (737, 351)]
# 31.0
# [(219, 82), (-85, 255), (377, 75), (741, 340)]
# 32.0624390837628
# [(221, 83), (-81, 258), (376, 79), (738, 346)]
# 29.068883707497267
# [(221, 83), (-81, 258), (380, 76), (739, 347)]
# 31.0
# [(221, 86), (-83, 258), (377, 80), (737, 351)]
# 27.018512172212592
# [(222, 85), (-80, 260), (377, 80), (737, 351)]
# 28.0178514522438
# [(222, 86), (-80, 261), (377, 76), (741, 340)]
# 29.017236257093817
# [(221, 87), (-82, 259), (379, 78), (738, 349)]
# 28.0
# [(221, 89), (-84, 259), (377, 76), (741, 340)]
# 28.0178514522438
# [(222, 88), (-81, 261), (378, 79), (737, 350)]
# 27.0
# [(221, 90), (-84, 260), (380, 77), (739, 348)]
# 27.0
# [(223, 87), (-79, 262), (378, 79), (737, 350)]
# 27.0
# [(223, 93), (-82, 263), (378, 78), (738, 349)]
# 25.0
# [(224, 89), (-78, 264), (384, 76), (738, 353)]
# 28.284271247461902
# [(228, 82), (-68, 267), (384, 74), (741, 348)]
# 32.55764119219941
# [(226, 93), (-76, 268), (383, 72), (742, 343)]
# 28.284271247461902
# [(228, 89), (-71, 269), (383, 72), (743, 343)]
# 30.4138126514911
# [(224, 102), (-84, 266), (379, 72), (743, 337)]
# 23.021728866442675
# [(229, 89), (-71, 270), (381, 70), (745, 335)]
# 31.400636936215164
# [(227, 88), (-72, 268), (383, 72), (743, 343)]
# 30.4138126514911
# [(227, 88), (-72, 268), (383, 72), (743, 342)]
# 30.4138126514911
# [(227, 87), (-72, 267), (381, 74), (741, 345)]
# 30.265491900843113
# [(233, 83), (-60, 274), (383, 72), (743, 343)]
# 33.95585369269929
# [(231, 87), (-65, 272), (386, 74), (740, 351)]
# 31.04834939252005
# [(234, 82), (-57, 275), (381, 74), (741, 345)]
# 32.7566787083184
# [(227, 88), (-72, 268), (383, 72), (743, 343)]
# 30.4138126514911
# [(234, 85), (-59, 275), (381, 69), (745, 334)]
# 33.734255586866
# [(234, 86), (-58, 276), (379, 73), (743, 337)]
# 31.575306807693888
# [(233, 86), (-62, 274), (380, 71), (744, 335)]
# 32.55764119219941
# [(234, 85), (-59, 275), (380, 72), (744, 336)]
# 32.7566787083184
# [(234, 85), (-59, 275), (378, 69), (747, 327)]
# 33.54101966249684
# [(236, 82), (-53, 278), (379, 68), (747, 326)]
# 35.6931365951495
# [(231, 90), (-67, 272), (380, 67), (748, 325)]
# 32.38826948140329
# [(233, 83), (-60, 274), (378, 69), (747, 327)]
# 34.36568055487916
# [(230, 91), (-69, 271), (378, 69), (747, 327)]
# 30.265491900843113
# [(234, 82), (-57, 275), (380, 71), (744, 335)]
# 34.713109915419565
# [(228, 102), (-77, 272), (381, 69), (745, 334)]
# 25.317977802344327
# [(231, 93), (-68, 273), (381, 71), (745, 335)]
# 28.635642126552707
# [(232, 89), (-64, 274), (378, 70), (746, 328)]
# 31.400636936215164
# [(229, 101), (-74, 273), (383, 66), (748, 331)]
# 27.65863337187866
# [(232, 95), (-67, 276), (379, 68), (747, 326)]
# 29.427877939124322
# [(233, 83), (-60, 274), (380, 72), (744, 336)]
# 33.54101966249684
# [(233, 83), (-60, 274), (376, 72), (745, 330)]
# 33.24154027718932
# [(233, 83), (-60, 274), (382, 71), (744, 338)]
# 33.734255586866
# [(233, 83), (-60, 274), (379, 70), (746, 331)]
# 34.52535300326414
# [(226, 83), (-71, 266), (386, 69), (745, 340)]
# 34.52535300326414
# [(230, 79), (-63, 269), (378, 72), (744, 333)]
# 35.22782990761707
# [(230, 78), (-63, 269), (386, 69), (745, 340)]
# 37.8549864614954
# [(229, 78), (-63, 269), (379, 68), (747, 326)]
# 37.21558813185679
# [(231, 81), (-62, 271), (381, 70), (745, 335)]
# 35.510561809129406
# [(228, 78), (-67, 266), (380, 72), (744, 336)]
# 35.22782990761707
# [(225, 83), (-74, 264), (382, 74), (741, 344)]
# 32.14031735997639
# [(227, 80), (-69, 266), (380, 72), (744, 336)]
# 34.132096331752024
# [(227, 80), (-69, 266), (381, 71), (745, 335)]
# 35.22782990761707
# [(223, 84), (-77, 261), (380, 76), (740, 347)]
# 30.01666203960727
# [(224, 82), (-75, 262), (379, 71), (745, 332)]
# 34.0147027033899
# [(220, 88), (-85, 257), (381, 70), (745, 335)]
# 31.0
# [(224, 76), (-72, 262), (372, 73), (745, 324)]
# 36.05551275463989
# [(224, 83), (-75, 263), (377, 71), (745, 329)]
# 33.0
# [(224, 83), (-75, 263), (381, 71), (745, 335)]
# 33.06055050963308
# [(226, 78), (-70, 264), (382, 71), (743, 339)]
# 36.22154055254967
# [(224, 88), (-78, 263), (379, 68), (747, 326)]
# 32.01562118716424
# [(222, 95), (-84, 262), (379, 72), (743, 337)]
# 27.0
# [(223, 87), (-79, 262), (380, 69), (746, 331)]
# 32.01562118716424
# [(224, 82), (-75, 262), (383, 69), (745, 337)]
# 35.12833614050059
# [(228, 80), (-66, 268), (379, 68), (748, 326)]
# 36.124783736376884
# [(223, 81), (-76, 261), (377, 70), (746, 328)]
# 35.0
# [(223, 81), (-76, 261), (386, 71), (743, 344)]
# 34.23448553724738
# [(226, 82), (-72, 265), (380, 71), (744, 335)]
# 34.132096331752024
# [(226, 82), (-71, 265), (378, 69), (747, 327)]
# 35.05709628591621
# [(228, 83), (-67, 268), (378, 69), (747, 327)]
# 34.132096331752024
# [(226, 83), (-71, 266), (378, 69), (747, 327)]
# 34.058772731852805
# [(226, 83), (-71, 266), (375, 73), (744, 331)]
# 32.0
# [(224, 85), (-77, 263), (377, 70), (746, 328)]
# 33.0
# [(230, 85), (-66, 270), (376, 72), (744, 331)]
# 32.14031735997639
# [(225, 87), (-76, 264), (375, 74), (743, 332)]
# 30.0
# [(224, 89), (-78, 264), (374, 79), (738, 344)]
# 26.019223662515376
# [(228, 85), (-69, 268), (372, 74), (745, 325)]
# 31.0
# [(225, 84), (-74, 265), (371, 74), (744, 326)]
# 31.064449134018133
# [(228, 83), (-67, 268), (374, 75), (743, 333)]
# 31.016124838541646
# [(227, 87), (-72, 267), (370, 79), (741, 334)]
# 27.073972741361768
# [(224, 89), (-78, 264), (373, 81), (737, 345)]
# 25.079872407968907
# [(224, 92), (-80, 264), (373, 81), (737, 345)]
# 24.08318915758459
# [(223, 94), (-82, 264), (369, 82), (737, 340)]
# 22.360679774997898
# [(225, 90), (-77, 265), (371, 80), (739, 338)]
# 25.079872407968907
# [(226, 82), (-72, 265), (374, 79), (738, 344)]
# 30.0
# [(226, 82), (-72, 265), (373, 77), (741, 335)]
# 31.016124838541646
# [(226, 82), (-72, 265), (373, 81), (737, 345)]
# 29.017236257093817
# [(222, 79), (-77, 259), (374, 77), (741, 338)]
# 32.0624390837628
# [(221, 79), (-80, 257), (374, 79), (738, 344)]
# 31.144823004794873
# [(219, 80), (-83, 255), (374, 80), (738, 344)]
# 30.265491900843113
# [(222, 79), (-77, 259), (372, 82), (736, 347)]
# 30.14962686336267
# [(219, 82), (-85, 255), (374, 79), (738, 344)]
# 30.265491900843113
# [(221, 80), (-79, 258), (371, 84), (735, 348)]
# 28.284271247461902
# [(220, 82), (-82, 257), (365, 83), (739, 335)]
# 29.120439557122072
# [(221, 77), (-78, 258), (368, 83), (737, 341)]
# 30.59411708155671
# [(219, 80), (-83, 255), (370, 81), (738, 339)]
# 30.59411708155671
# [(221, 77), (-78, 258), (369, 86), (733, 351)]
# 29.427877939124322
# [(219, 79), (-83, 254), (374, 85), (733, 356)]
# 28.284271247461902
# [(215, 85), (-93, 250), (374, 84), (733, 355)]
# 26.68332812825267
# [(221, 73), (-77, 256), (374, 84), (733, 355)]
# 32.14031735997639
# [(218, 78), (-84, 253), (376, 83), (733, 357)]
# 30.14962686336267
# [(218, 79), (-84, 254), (372, 85), (734, 352)]
# 28.442925306655784
# [(219, 73), (-80, 253), (378, 79), (737, 350)]
# 34.058772731852805
# [(217, 77), (-85, 252), (378, 84), (732, 361)]
# 30.14962686336267
# [(218, 72), (-81, 253), (376, 82), (735, 352)]
# 33.13608305156178
# [(217, 77), (-85, 252), (378, 83), (733, 360)]
# 30.14962686336267
# [(220, 76), (-79, 256), (376, 86), (731, 363)]
# 29.068883707497267
# [(220, 76), (-79, 256), (372, 91), (727, 368)]
# 27.294688127912362
# [(220, 76), (-79, 256), (375, 87), (730, 364)]
# 29.154759474226502
# [(216, 74), (-86, 249), (377, 85), (731, 362)]
# 31.25699921617557
# [(216, 74), (-86, 249), (374, 89), (728, 366)]
# 29.427877939124322
# [(214, 76), (-92, 246), (375, 92), (725, 375)]
# 26.68332812825267
# [(215, 73), (-87, 248), (373, 95), (723, 378)]
# 26.68332812825267
# [(215, 73), (-87, 248), (373, 95), (722, 378)]
# 26.68332812825267
# [(215, 73), (-87, 248), (372, 91), (727, 368)]
# 28.861739379323623
# [(214, 74), (-90, 246), (372, 91), (727, 368)]
# 28.861739379323623
# [(214, 74), (-90, 246), (372, 96), (721, 379)]
# 25.96150997149434
# [(212, 76), (-95, 243), (371, 97), (721, 380)]
# 25.632011235952593
# [(213, 75), (-92, 244), (378, 96), (720, 388)]
# 25.495097567963924
# [(210, 76), (-98, 240), (374, 98), (718, 387)]
# 24.351591323771842
# [(208, 84), (-106, 237), (367, 102), (717, 385)]
# 21.400934559032695
# [(210, 78), (-100, 240), (372, 100), (716, 390)]
# 22.847319317591726
# [(207, 86), (-108, 236), (373, 99), (718, 388)]
# 20.591260281974
# [(210, 70), (-95, 240), (372, 100), (716, 390)]
# 26.570660511172846
# [(209, 75), (-99, 239), (372, 105), (712, 400)]
# 22.360679774997898
# [(209, 75), (-99, 239), (373, 104), (712, 399)]
# 22.847319317591726
# [(210, 69), (-95, 239), (373, 106), (710, 404)]
# 24.698178070456937
# [(205, 72), (-106, 231), (374, 107), (708, 408)]
# 23.706539182259394
# [(205, 72), (-106, 231), (379, 106), (708, 413)]
# 22.47220505424423
# [(205, 72), (-106, 231), (373, 103), (713, 398)]
# 25.495097567963924
# [(205, 72), (-106, 231), (369, 112), (704, 413)]
# 22.20360331117452
# [(205, 75), (-107, 231), (374, 111), (703, 418)]
# 20.248456731316587
# [(204, 71), (-106, 230), (366, 115), (701, 416)]
# 22.67156809750927
# [(202, 72), (-112, 226), (368, 116), (699, 420)]
# 21.93171219946131
# [(207, 67), (-100, 234), (375, 115), (699, 427)]
# 21.02379604162864
# [(206, 68), (-102, 232), (370, 115), (699, 422)]
# 22.47220505424423
# [(204, 70), (-107, 229), (365, 118), (697, 422)]
# 22.627416997969522
# [(205, 66), (-103, 230), (365, 120), (694, 427)]
# 22.67156809750927
# [(203, 69), (-108, 228), (365, 121), (694, 428)]
# 21.93171219946131
# [(202, 70), (-110, 226), (364, 118), (698, 419)]
# 23.345235059857504
# [(203, 69), (-108, 228), (360, 126), (689, 433)]
# 23.021728866442675
# [(196, 83), (-126, 216), (364, 126), (688, 439)]
# 20.8806130178211
# [(201, 65), (-110, 224), (363, 123), (692, 430)]
# 24.08318915758459
# [(201, 69), (-113, 223), (358, 125), (692, 426)]
# 24.698178070456937
# [(201, 69), (-113, 223), (360, 126), (689, 433)]
# 23.853720883753127
# [(199, 72), (-117, 220), (361, 129), (685, 442)]
# 22.360679774997898
# [(199, 72), (-117, 220), (358, 128), (687, 435)]
# 24.166091947189145
# [(199, 72), (-117, 220), (361, 127), (687, 437)]
# 22.825424421026653
# [(199, 72), (-117, 220), (364, 124), (690, 434)]
# 22.47220505424423
# [(199, 72), (-117, 220), (358, 126), (690, 430)]
# 24.596747752497688
# [(199, 67), (-114, 220), (358, 126), (690, 430)]
# 26.076809620810597
# [(198, 70), (-118, 218), (358, 126), (690, 430)]
# 25.059928172283335
# [(199, 70), (-115, 221), (362, 124), (691, 431)]
# 23.853720883753127
# [(198, 71), (-118, 219), (362, 124), (691, 431)]
# 23.853720883753127
# [(198, 71), (-118, 219), (361, 129), (685, 442)]
# 23.259406699226016
# [(198, 71), (-118, 219), (354, 133), (683, 440)]
# 25.298221281347036
# [(199, 72), (-117, 220), (354, 133), (683, 440)]
# 25.298221281347036
# [(199, 72), (-117, 220), (354, 133), (683, 440)]
# 25.298221281347036
# [(199, 72), (-117, 220), (354, 133), (683, 440)]
# 25.298221281347036
# [(199, 73), (-117, 220), (354, 133), (683, 440)]
# 25.0
# [(198, 76), (-121, 219), (354, 133), (683, 440)]
# 24.73863375370596
# [(198, 76), (-121, 218), (354, 133), (683, 440)]
# 24.73863375370596
# [(201, 70), (-113, 224), (352, 131), (686, 432)]
# 26.0
# [(200, 80), (-119, 222), (352, 131), (686, 432)]
# 24.515301344262525
# [(201, 77), (-115, 225), (351, 129), (691, 424)]
# 25.0
# [(200, 78), (-117, 223), (351, 129), (691, 424)]
# 25.96150997149434
# [(201, 80), (-116, 225), (351, 129), (691, 424)]
# 24.73863375370596
# [(201, 81), (-116, 226), (359, 123), (694, 424)]
# 21.540659228538015
# [(205, 76), (-107, 232), (359, 123), (694, 424)]
# 21.095023109728988
# [(203, 80), (-114, 228), (359, 123), (694, 424)]
# 21.02379604162864
# [(203, 80), (-114, 228), (359, 123), (694, 424)]
# 21.02379604162864
# [(209, 79), (-102, 238), (361, 117), (700, 413)]
# 19.209372712298546
# [(209, 79), (-102, 238), (370, 111), (704, 412)]
# 18.601075237738275
# [(209, 79), (-102, 238), (369, 115), (700, 419)]
# 17.029386365926403
# [(209, 80), (-102, 239), (377, 108), (706, 415)]
# 17.46424919657298
# [(208, 85), (-106, 238), (372, 117), (696, 430)]
# 13.45362404707371
# [(210, 82), (-101, 241), (374, 115), (698, 428)]
# 14.422205101855956
# [(211, 81), (-98, 243), (378, 111), (702, 424)]
# 15.231546211727817
# [(211, 83), (-100, 242), (378, 104), (710, 408)]
# 18.027756377319946
# [(213, 82), (-95, 246), (378, 107), (707, 413)]
# 16.76305461424021
# [(212, 86), (-99, 244), (382, 102), (711, 409)]
# 16.278820596099706
# [(213, 85), (-97, 246), (382, 102), (711, 409)]
# 17.26267650163207
# [(213, 87), (-98, 246), (385, 95), (719, 396)]
# 19.026297590440446
# [(211, 90), (-103, 244), (388, 96), (718, 402)]
# 17.029386365926403
# [(213, 88), (-98, 247), (385, 94), (720, 395)]
# 19.026297590440446
# [(214, 87), (-95, 249), (387, 95), (718, 399)]
# 19.0
# [(215, 85), (-93, 250), (385, 94), (720, 395)]
# 21.0
# [(216, 84), (-90, 251), (389, 90), (724, 391)]
# 23.08679276123039
# [(213, 95), (-101, 248), (390, 84), (729, 379)]
# 21.02379604162864
# [(217, 86), (-90, 253), (386, 88), (726, 383)]
# 23.021728866442675
# [(219, 80), (-83, 255), (395, 84), (729, 385)]
# 28.861739379323623
# [(220, 81), (-82, 256), (390, 83), (730, 379)]
# 28.442925306655784
# [(219, 89), (-88, 256), (392, 77), (736, 366)]
# 27.459060435491963
# [(219, 97), (-90, 258), (394, 80), (733, 375)]
# 22.80350850198276
# [(221, 89), (-84, 259), (397, 76), (736, 372)]
# 29.410882339705484
# [(221, 90), (-84, 260), (393, 72), (741, 358)]
# 29.832867780352597
# [(221, 90), (-84, 260), (391, 69), (743, 350)]
# 31.575306807693888
# [(225, 90), (-77, 265), (392, 71), (742, 354)]
# 31.04834939252005
# [(221, 92), (-86, 259), (391, 62), (750, 333)]
# 33.54101966249684
# [(226, 89), (-74, 266), (388, 71), (743, 348)]
# 30.805843601498726
# [(223, 93), (-82, 263), (390, 68), (745, 345)]
# 30.59411708155671
# [(226, 92), (-76, 267), (387, 66), (747, 337)]
# 31.575306807693888
# [(225, 91), (-77, 266), (390, 68), (745, 345)]
# 31.78049716414141
# [(226, 93), (-76, 268), (383, 65), (749, 326)]
# 31.25699921617557
# [(226, 93), (-76, 268), (380, 66), (749, 324)]
# 31.144823004794873
# [(227, 94), (-75, 269), (385, 59), (754, 317)]
# 34.52535300326414
# [(227, 94), (-75, 269), (385, 59), (754, 317)]
# 34.52535300326414
# [(226, 98), (-79, 268), (385, 61), (752, 323)]
# 31.400636936215164
# [(228, 96), (-74, 271), (391, 56), (755, 320)]
# 35.17101079013795
# [(228, 99), (-75, 272), (393, 58), (753, 329)]
# 33.52610922848042
# [(232, 95), (-67, 276), (382, 58), (756, 309)]
# 34.713109915419565
# [(229, 103), (-76, 273), (379, 63), (752, 314)]
# 27.294688127912362
# [(231, 100), (-71, 275), (380, 59), (755, 308)]
# 31.400636936215164
# [(233, 100), (-68, 278), (388, 55), (756, 313)]
# 34.48187929913333
# [(234, 99), (-65, 280), (388, 54), (757, 313)]
# 35.73513677041127
# [(236, 94), (-60, 280), (390, 52), (759, 310)]
# 39.21734310225516
# [(235, 96), (-63, 279), (389, 54), (757, 312)]
# 37.0
# [(235, 96), (-63, 279), (387, 56), (755, 315)]
# 35.73513677041127
# [(238, 91), (-54, 282), (389, 53), (758, 311)]
# 40.162171256046406
# [(241, 93), (-50, 286), (389, 57), (755, 318)]
# 38.07886552931954
# [(241, 93), (-50, 286), (386, 58), (755, 316)]
# 37.33630940518894
# [(238, 94), (-56, 282), (389, 59), (753, 323)]
# 36.40054944640259
# [(237, 96), (-59, 282), (387, 51), (760, 303)]
# 38.897300677553446
# [(240, 95), (-52, 285), (387, 57), (755, 315)]
# 36.40054944640259
# [(243, 93), (-46, 288), (394, 52), (758, 316)]
# 42.04759208325728
# [(242, 91), (-47, 287), (390, 52), (759, 310)]
# 42.15447781671598
# [(241, 96), (-51, 287), (386, 52), (759, 303)]
# 38.27531841800928
# [(243, 95), (-48, 288), (391, 56), (755, 320)]
# 38.91015291668744
# [(244, 94), (-45, 290), (392, 54), (756, 319)]
# 40.24922359499622
# [(241, 96), (-51, 287), (388, 53), (758, 308)]
# 38.62641583165593
# [(241, 96), (-51, 287), (391, 51), (759, 309)]
# 40.311288741492746
# [(243, 96), (-48, 289), (393, 59), (752, 330)]
# 37.589892258425
# [(235, 115), (-70, 285), (384, 55), (758, 306)]
# 26.570660511172846
# [(241, 103), (-55, 289), (394, 55), (755, 323)]
# 35.35533905932738
# [(248, 84), (-32, 292), (393, 54), (757, 318)]
# 45.617978911828175
# [(248, 87), (-34, 293), (386, 53), (759, 304)]
# 43.46262762420146
# [(248, 86), (-34, 292), (388, 53), (758, 308)]
# 44.77722635447622
# [(246, 90), (-40, 290), (393, 54), (757, 318)]
# 42.485291572496
# [(246, 90), (-40, 290), (394, 55), (756, 323)]
# 42.941821107167776
# [(246, 90), (-40, 290), (385, 53), (758, 305)]
# 41.78516483155236
# [(252, 86), (-26, 296), (386, 52), (759, 303)]
# 45.18849411078001
# [(237, 91), (-55, 281), (388, 54), (757, 313)]
# 39.84971769034255
# [(245, 85), (-39, 288), (388, 55), (756, 313)]
# 43.08131845707603
# [(246, 87), (-38, 290), (392, 55), (756, 319)]
# 43.382023926967726
# [(243, 89), (-45, 287), (388, 60), (752, 325)]
# 39.0
# [(244, 87), (-42, 288), (390, 57), (754, 322)]
# 41.6293165929973
# [(241, 89), (-48, 285), (387, 59), (753, 320)]
# 38.62641583165593
# [(243, 85), (-43, 286), (385, 59), (753, 317)]
# 40.496913462633174
# [(246, 84), (-36, 289), (386, 58), (755, 316)]
# 42.15447781671598
# [(244, 81), (-38, 287), (387, 56), (756, 314)]
# 44.598206241955516
# [(246, 83), (-36, 289), (380, 58), (755, 307)]
# 42.05948168962618
# [(244, 80), (-38, 286), (389, 58), (753, 323)]
# 44.01136216933077
# [(241, 93), (-50, 286), (381, 57), (756, 306)]
# 36.68787265568828
# [(240, 88), (-49, 284), (385, 59), (753, 317)]
# 38.897300677553446
# [(244, 80), (-38, 286), (382, 58), (755, 310)]
# 43.01162633521314
# [(239, 93), (-53, 284), (380, 61), (753, 313)]
# 34.20526275297414
# [(239, 93), (-53, 284), (387, 57), (755, 315)]
# 37.33630940518894
# [(242, 85), (-43, 285), (382, 58), (755, 310)]
# 40.80441152620633
# [(241, 90), (-48, 285), (376, 62), (754, 307)]
# 34.92849839314596
# [(244, 87), (-42, 288), (380, 62), (753, 313)]
# 37.94733192202055
# [(241, 83), (-45, 284), (380, 61), (753, 313)]
# 39.293765408777
# [(241, 83), (-45, 284), (375, 61), (755, 303)]
# 38.8329756778952
# [(241, 83), (-45, 284), (376, 63), (753, 308)]
# 37.8549864614954
# [(243, 80), (-39, 285), (381, 60), (754, 312)]
# 41.7612260356422
# [(237, 84), (-52, 280), (382, 61), (753, 316)]
# 39.05124837953327
# [(238, 85), (-51, 280), (376, 63), (753, 308)]
# 36.6742416417845
# [(241, 86), (-47, 284), (374, 61), (756, 299)]
# 37.656340767525464
# [(244, 80), (-38, 286), (381, 60), (754, 312)]
# 41.7612260356422
# [(242, 84), (-44, 285), (379, 63), (752, 315)]
# 38.3275357934736
# [(241, 86), (-47, 284), (386, 58), (755, 316)]
# 40.162171256046406
# [(240, 88), (-49, 284), (385, 59), (754, 317)]
# 38.897300677553446
# [(241, 86), (-46, 285), (377, 60), (755, 305)]
# 38.07886552931954
# [(240, 91), (-51, 284), (374, 65), (752, 310)]
# 32.7566787083184
# [(240, 88), (-49, 284), (383, 59), (754, 314)]
# 38.600518131237564
# [(236, 95), (-60, 280), (383, 59), (754, 314)]
# 34.20526275297414
# [(242, 84), (-44, 285), (382, 61), (753, 316)]
# 39.84971769034255
# [(242, 84), (-44, 285), (385, 61), (752, 322)]
# 40.162171256046406
# [(240, 94), (-53, 285), (383, 57), (756, 308)]
# 36.68787265568828
# [(242, 91), (-47, 286), (386, 63), (750, 327)]
# 35.84689665786984
# [(244, 87), (-42, 288), (381, 57), (756, 306)]
# 39.84971769034255
# [(243, 92), (-46, 288), (387, 59), (753, 321)]
# 38.07886552931954
# [(245, 86), (-39, 289), (384, 61), (752, 319)]
# 39.56008088970496
# [(242, 98), (-50, 289), (383, 63), (751, 321)]
# 32.31098884280702
# [(242, 98), (-50, 289), (385, 59), (753, 317)]
# 34.539832078341085
# [(248, 83), (-33, 291), (381, 59), (754, 311)]
# 41.43669871020132
# [(240, 87), (-50, 283), (382, 63), (751, 322)]
# 36.68787265568828
# [(237, 90), (-56, 280), (382, 63), (751, 322)]
# 35.17101079013795
# [(245, 85), (-39, 289), (382, 61), (753, 316)]
# 39.21734310225516
# [(241, 86), (-46, 285), (377, 61), (754, 306)]
# 38.07886552931954
# [(245, 89), (-41, 290), (387, 61), (751, 326)]
# 38.48376280978771
# [(247, 85), (-35, 291), (382, 59), (755, 310)]
# 40.496913462633174
# [(245, 88), (-41, 289), (387, 62), (751, 327)]
# 38.48376280978771
# [(245, 89), (-41, 290), (384, 61), (752, 319)]
# 37.69615364994153
# [(246, 87), (-38, 290), (386, 60), (753, 321)]
# 40.311288741492746
# [(247, 84), (-36, 290), (390, 58), (754, 322)]
# 42.95346318982906
# [(250, 77), (-25, 292), (385, 59), (753, 317)]
# 45.31004303683677
# [(242, 97), (-51, 287), (385, 59), (754, 317)]
# 34.539832078341085
# [(247, 92), (-38, 293), (390, 58), (754, 322)]
# 39.35733730830886
# [(243, 100), (-49, 290), (385, 59), (754, 317)]
# 34.0147027033899
# [(246, 96), (-43, 292), (384, 55), (757, 307)]
# 38.07886552931954
# [(249, 88), (-33, 293), (384, 58), (755, 313)]
# 40.311288741492746
# [(246, 97), (-43, 293), (384, 58), (755, 313)]
# 36.24913792078372
# [(249, 88), (-33, 294), (380, 56), (758, 301)]
# 40.496913462633174
# [(249, 88), (-33, 293), (386, 58), (754, 316)]
# 40.718546143004666
# [(250, 83), (-28, 294), (382, 53), (759, 299)]
# 44.94441010848846
# [(250, 83), (-28, 294), (385, 54), (758, 306)]
# 45.31004303683677
# [(242, 91), (-47, 287), (389, 59), (753, 323)]
# 38.07886552931954
# [(248, 93), (-38, 294), (387, 56), (755, 315)]
# 39.81205847478876
# [(247, 88), (-37, 291), (382, 58), (756, 309)]
# 39.56008088970496
# [(246, 90), (-40, 291), (386, 53), (759, 304)]
# 42.15447781671598
# [(250, 89), (-32, 295), (380, 52), (761, 290)]
# 42.720018726587654
# [(252, 89), (-28, 297), (377, 54), (761, 289)]
# 41.43669871020132
# [(251, 91), (-31, 297), (382, 54), (759, 299)]
# 41.23105625617661
# [(255, 89), (-24, 300), (384, 55), (758, 306)]
# 42.485291572496
# [(257, 85), (-18, 301), (385, 54), (758, 306)]
# 46.06517122512408
# [(255, 90), (-23, 300), (383, 51), (761, 296)]
# 44.28317965096906
# [(257, 89), (-20, 302), (385, 52), (760, 300)]
# 45.17742799230607
# [(256, 91), (-23, 301), (381, 54), (759, 299)]
# 42.04759208325728
# [(256, 91), (-22, 302), (376, 53), (761, 285)]
# 41.23105625617661
# [(256, 94), (-24, 302), (382, 48), (763, 287)]
# 43.382023926967726
# [(253, 104), (-34, 302), (380, 51), (762, 289)]
# 36.6742416417845
# [(259, 95), (-20, 305), (385, 48), (762, 293)]
# 44.77722635447622
# [(264, 88), (-7, 308), (385, 49), (762, 294)]
# 48.373546489791295
# [(259, 101), (-23, 307), (384, 50), (762, 295)]
# 40.8166632639171
# [(272, 84), (8, 314), (386, 48), (763, 293)]
# 52.69724850502159
# [(272, 84), (8, 314), (376, 47), (766, 272)]
# 51.0
# [(272, 84), (8, 314), (385, 49), (762, 294)]
# 52.15361924162119
# [(272, 84), (8, 314), (387, 49), (762, 297)]
# 52.69724850502159
# [(272, 84), (8, 314), (383, 46), (765, 284)]
# 52.478567053607705
# [(272, 84), (8, 314), (388, 47), (763, 296)]
# 54.08326913195984
# [(269, 87), (1, 312), (387, 45), (765, 290)]
# 52.15361924162119
# [(265, 92), (-8, 310), (381, 49), (763, 288)]
# 46.14108798023731
# [(270, 88), (2, 313), (388, 47), (763, 295)]
# 51.86520991955976
# [(276, 82), (16, 317), (389, 46), (764, 294)]
# 56.0357029044876
# [(276, 83), (16, 317), (391, 44), (765, 296)]
# 57.42821606144492
# [(277, 87), (15, 319), (393, 48), (762, 306)]
# 55.44366510251645
# [(277, 87), (15, 319), (396, 44), (764, 302)]
# 57.62811813689564
# [(277, 87), (15, 319), (401, 43), (765, 307)]
# 59.54829972383762
# [(278, 81), (20, 318), (391, 45), (764, 297)]
# 58.008620049092706
# [(280, 80), (24, 319), (398, 46), (763, 310)]
# 61.07372593840988
# [(274, 97), (4, 319), (398, 47), (762, 311)]
# 52.3450093132096
# [(273, 99), (1, 320), (400, 44), (764, 309)]
# 53.075418038862395
# [(281, 88), (21, 322), (402, 46), (762, 317)]
# 59.413803110051795
# [(283, 80), (29, 321), (406, 42), (765, 312)]
# 65.85590330410783
# [(282, 89), (21, 323), (411, 44), (763, 325)]
# 63.655321851358195
# [(279, 86), (19, 320), (412, 46), (762, 329)]
# 62.93647591023825
# [(279, 86), (19, 320), (412, 40), (767, 317)]
# 65.06919393998976
# [(279, 86), (19, 320), (414, 44), (763, 327)]
# 64.35060217278468
# [(279, 86), (19, 320), (422, 41), (767, 330)]
# 68.62215385719105
# [(279, 86), (19, 320), (423, 42), (765, 335)]
# 68.6804193347711
# [(279, 86), (19, 320), (429, 46), (763, 347)]
# 69.65629906907199
# [(282, 83), (26, 322), (435, 45), (764, 352)]
# 74.02702209328699
# [(282, 83), (26, 322), (433, 41), (767, 342)]
# 74.51845409024533
# [(284, 81), (30, 322), (433, 41), (767, 342)]
# 75.92759709091287
# [(286, 77), (37, 323), (433, 41), (767, 342)]
# 77.98717843338096
# [(282, 83), (26, 322), (433, 41), (767, 342)]
# 74.51845409024533
# [(283, 84), (27, 322), (433, 41), (767, 342)]
# 75.28612089887484
# [(284, 85), (29, 324), (433, 41), (767, 342)]
# 74.65252842335616
# [(284, 88), (26, 324), (433, 41), (767, 342)]
# 74.02702209328699
# [(283, 84), (27, 322), (433, 41), (767, 342)]
# 75.28612089887484
# [(282, 83), (26, 322), (433, 41), (767, 342)]
# 74.51845409024533
# [(284, 78), (32, 321), (433, 41), (767, 342)]
# 77.23341245859851
# [(285, 79), (33, 322), (433, 41), (767, 342)]
# 77.33692520394123
# [(287, 88), (31, 327), (433, 41), (767, 342)]
# 75.6042326857432
# [(287, 87), (31, 326), (433, 41), (767, 342)]
# 75.6042326857432
# [(285, 73), (38, 321), (433, 41), (767, 342)]
# 79.30952023559341
# [(282, 79), (28, 320), (433, 41), (767, 342)]
# 75.82216034906945
# [(282, 79), (28, 320), (433, 41), (767, 342)]
# 75.82216034906945
# [(282, 79), (28, 320), (433, 41), (767, 342)]
# 75.82216034906945
# [(282, 79), (28, 320), (433, 41), (767, 342)]
# 75.82216034906945
# [(282, 79), (28, 320), (433, 41), (767, 342)]
# 75.82216034906945
# [(282, 79), (28, 320), (433, 41), (767, 342)]
# 75.82216034906945
# [(286, 74), (38, 321), (433, 41), (767, 342)]
# 79.30952023559341
# [(265, 89), (-6, 310), (433, 41), (767, 342)]
# 66.52818951391959
# [(276, 76), (20, 315), (433, 41), (767, 342)]
# 74.96665925596525
# [(273, 79), (13, 313), (433, 41), (767, 342)]
# 72.86288492778748
# [(272, 78), (12, 312), (433, 41), (767, 342)]
# 72.83543093852057
# [(272, 78), (12, 312), (433, 41), (767, 342)]
# 72.83543093852057
# [(273, 75), (15, 312), (433, 41), (767, 342)]
# 74.24957912338628
# [(273, 86), (9, 316), (433, 41), (767, 342)]
# 70.83784299369935
# [(271, 83), (7, 313), (433, 41), (767, 342)]
# 70.76722405181653
# [(271, 84), (7, 313), (433, 41), (767, 342)]
# 70.76722405181653
# [(270, 76), (10, 310), (433, 41), (767, 342)]
# 72.83543093852057
# [(274, 80), (13, 314), (433, 41), (767, 342)]
# 72.86288492778748
# [(276, 70), (24, 313), (433, 41), (767, 342)]
# 77.07788269017254
# [(273, 79), (13, 313), (433, 41), (767, 342)]
# 72.86288492778748
# [(270, 76), (10, 310), (433, 41), (767, 342)]
# 72.83543093852057
# [(268, 68), (12, 307), (433, 41), (767, 342)]
# 75.07329751649384
# [(268, 68), (12, 307), (433, 41), (767, 342)]
# 75.07329751649384
# [(268, 68), (12, 307), (433, 41), (767, 342)]
# 75.07329751649384
# [(268, 68), (12, 307), (433, 41), (767, 342)]
# 75.07329751649384
# [(268, 68), (12, 307), (433, 41), (767, 342)]
# 75.07329751649384
# [(268, 68), (12, 307), (433, 41), (767, 342)]
# 75.07329751649384
# [(268, 68), (12, 307), (433, 41), (767, 342)]
# 75.07329751649384
# [(267, 67), (11, 306), (433, 41), (767, 342)]
# 75.07329751649384
# [(262, 73), (-1, 303), (433, 41), (767, 342)]
# 70.83784299369935
# [(267, 66), (11, 305), (433, 41), (767, 342)]
# 75.82216034906945
# [(264, 69), (4, 304), (433, 41), (767, 342)]
# 73.0
# [(264, 69), (4, 304), (433, 41), (767, 342)]
# 73.0
# [(261, 72), (-2, 301), (433, 41), (767, 342)]
# 71.58910531638176
# [(261, 69), (0, 301), (433, 41), (767, 342)]
# 72.34638899074369
# [(257, 79), (-14, 299), (433, 41), (767, 342)]
# 67.26812023536856
# [(266, 62), (12, 303), (433, 41), (767, 342)]
# 76.69419795525604
# [(257, 85), (-18, 301), (433, 41), (767, 342)]
# 65.06919393998976
# [(260, 77), (-7, 302), (433, 41), (767, 342)]
# 68.6804193347711
# [(261, 72), (-2, 301), (433, 41), (767, 342)]
# 71.58910531638176
# [(257, 79), (-14, 299), (433, 41), (767, 342)]
# 67.26812023536856
# [(258, 74), (-9, 299), (433, 41), (767, 342)]
# 69.52697318307479
# [(254, 75), (-17, 296), (433, 41), (767, 342)]
# 67.47592163134935
# [(253, 74), (-18, 294), (433, 41), (767, 342)]
# 68.24954212300622
# [(253, 74), (-18, 294), (433, 41), (767, 342)]
# 68.24954212300622
# [(253, 74), (-18, 294), (433, 41), (767, 342)]
# 68.24954212300622
# [(253, 74), (-18, 294), (433, 41), (767, 342)]
# 68.24954212300622
# [(257, 73), (-10, 298), (433, 41), (767, 342)]
# 69.52697318307479
# [(243, 83), (-41, 286), (433, 41), (767, 342)]
# 61.220911460055866
# [(248, 76), (-29, 289), (433, 41), (767, 342)]
# 65.60487786742691
# [(248, 74), (-27, 290), (433, 41), (767, 342)]
# 66.40030120413611
# [(249, 78), (-28, 291), (433, 41), (767, 342)]
# 65.43699259593154
# [(251, 72), (-20, 292), (433, 41), (767, 342)]
# 68.41052550594829
# [(245, 82), (-37, 288), (433, 41), (767, 342)]
# 62.625873247404705
# [(246, 81), (-34, 289), (433, 41), (767, 342)]
# 62.625873247404705
# [(248, 80), (-30, 291), (433, 41), (767, 342)]
# 64.03124237432849
# [(240, 85), (-47, 283), (373, 67), (750, 312)]
# 34.52535300326414
# [(243, 86), (-43, 287), (369, 69), (751, 307)]
# 33.54101966249684
# [(244, 81), (-38, 287), (366, 73), (748, 312)]
# 33.37663853655727
# [(247, 79), (-32, 289), (370, 70), (749, 312)]
# 36.87817782917155
# [(245, 76), (-33, 287), (374, 70), (747, 322)]
# 38.07886552931954
# [(245, 76), (-33, 287), (371, 70), (749, 315)]
# 37.8549864614954
# [(243, 79), (-40, 285), (375, 71), (746, 326)]
# 36.138621999185304
# [(241, 83), (-45, 284), (374, 75), (743, 333)]
# 31.78049716414141
# [(237, 87), (-53, 280), (379, 68), (747, 326)]
# 33.95585369269929
# [(236, 88), (-57, 279), (380, 71), (744, 336)]
# 32.01562118716424
# [(236, 85), (-55, 278), (381, 69), (745, 334)]
# 33.95585369269929
# [(235, 86), (-58, 277), (374, 70), (747, 322)]
# 32.2490309931942
# [(231, 86), (-65, 272), (375, 70), (746, 325)]
# 32.14031735997639
# [(236, 85), (-55, 278), (379, 70), (746, 331)]
# 33.734255586866
# [(235, 84), (-56, 277), (379, 70), (746, 331)]
# 33.734255586866
# [(234, 86), (-58, 276), (385, 70), (744, 340)]
# 33.24154027718932
# [(234, 85), (-59, 275), (383, 70), (744, 338)]
# 33.95585369269929
# [(236, 81), (-53, 277), (398, 80), (733, 381)]
# 34.48187929913333
# [(235, 83), (-56, 277), (370, 72), (747, 317)]
# 33.06055050963308
# [(234, 82), (-57, 275), (382, 71), (744, 338)]
# 34.92849839314596
# [(230, 92), (-69, 272), (384, 70), (744, 341)]
# 29.832867780352597
# [(229, 90), (-70, 271), (388, 71), (743, 348)]
# 31.04834939252005
# [(236, 76), (-50, 276), (389, 75), (739, 358)]
# 37.0
# [(236, 79), (-52, 277), (384, 71), (743, 342)]
# 36.40054944640259
# [(234, 85), (-59, 275), (400, 80), (732, 384)]
# 32.7566787083184
# [(232, 89), (-64, 274), (393, 75), (738, 364)]
# 30.463092423455635
# [(232, 88), (-64, 273), (391, 77), (736, 367)]
# 30.083217912982647
# [(232, 89), (-64, 274), (388, 71), (743, 348)]
# 31.622776601683793
# [(232, 88), (-64, 273), (387, 78), (736, 361)]
# 28.460498941515414
# [(231, 83), (-63, 271), (399, 79), (733, 380)]
# 32.64965543462902
# [(231, 83), (-63, 271), (395, 73), (740, 362)]
# 34.539832078341085
# [(231, 83), (-63, 271), (394, 71), (741, 357)]
# 35.11409973215888
# [(228, 86), (-69, 269), (396, 72), (740, 361)]
# 33.24154027718932
# [(234, 85), (-59, 275), (392, 71), (741, 355)]
# 34.539832078341085
# [(229, 87), (-68, 270), (392, 74), (739, 360)]
# 31.622776601683793
# [(229, 89), (-71, 270), (397, 78), (734, 376)]
# 29.966648127543394
# [(230, 85), (-66, 271), (400, 75), (737, 373)]
# 33.54101966249684
# [(228, 89), (-71, 269), (401, 71), (740, 367)]
# 33.1058907144937
# [(229, 89), (-71, 270), (400, 78), (735, 379)]
# 30.4138126514911
# [(231, 86), (-65, 272), (393, 70), (743, 353)]
# 34.17601498127012
# [(228, 89), (-71, 269), (397, 74), (739, 366)]
# 31.38470965295043
# [(229, 90), (-70, 271), (401, 71), (740, 367)]
# 33.54101966249684
# [(228, 92), (-73, 269), (402, 78), (734, 382)]
# 29.154759474226502
# [(228, 95), (-74, 270), (401, 71), (740, 367)]
# 30.4138126514911
# [(225, 100), (-82, 267), (400, 75), (737, 373)]
# 25.942243542145693
# [(229, 97), (-73, 272), (397, 75), (737, 370)]
# 27.294688127912362
# [(230, 92), (-69, 272), (397, 76), (736, 371)]
# 29.068883707497267
# [(232, 88), (-64, 273), (399, 71), (741, 363)]
# 34.438350715445125
# [(231, 94), (-68, 274), (400, 73), (739, 368)]
# 30.886890422961002
# [(232, 89), (-64, 274), (401, 71), (741, 366)]
# 34.0
# [(228, 92), (-72, 270), (398, 74), (738, 370)]
# 29.966648127543394
# [(228, 92), (-72, 270), (397, 70), (742, 359)]
# 31.38470965295043
# [(228, 92), (-72, 270), (399, 74), (738, 369)]
# 29.966648127543394
# [(227, 96), (-77, 269), (397, 70), (742, 359)]
# 29.546573405388315
# [(231, 93), (-68, 273), (399, 67), (744, 357)]
# 33.54101966249684
# [(228, 96), (-74, 271), (399, 68), (743, 357)]
# 30.870698080866262
# [(230, 95), (-71, 273), (399, 71), (741, 363)]
# 30.4138126514911
# [(232, 95), (-67, 275), (396, 66), (746, 349)]
# 33.1058907144937
# [(231, 94), (-68, 274), (396, 66), (746, 349)]
# 32.69556544854363
# [(232, 95), (-67, 275), (397, 65), (746, 348)]
# 33.1058907144937
# [(235, 93), (-61, 278), (397, 65), (746, 348)]
# 34.88552708502482
# [(235, 91), (-59, 279), (394, 66), (746, 346)]
# 34.92849839314596
# [(232, 96), (-67, 276), (394, 66), (746, 346)]
# 31.78049716414141
# [(229, 101), (-74, 273), (392, 66), (746, 343)]
# 28.792360097775937
# [(231, 104), (-73, 276), (392, 66), (746, 343)]
# 27.313000567495326
# [(230, 106), (-75, 276), (396, 66), (746, 349)]
# 27.294688127912362
# [(232, 109), (-73, 279), (394, 68), (744, 351)]
# 25.553864678361276
# [(237, 100), (-61, 283), (393, 64), (747, 342)]
# 31.76476034853718
# [(236, 103), (-63, 283), (393, 64), (748, 341)]
# 30.4138126514911
# [(240, 97), (-55, 285), (395, 64), (748, 344)]
# 34.48187929913333
# [(239, 96), (-55, 284), (390, 63), (749, 334)]
# 34.0147027033899
# [(240, 101), (-56, 286), (384, 61), (752, 319)]
# 31.38470965295043
# [(240, 101), (-56, 286), (380, 64), (751, 319)]
# 29.732137494637012
# [(243, 99), (-50, 290), (378, 65), (751, 316)]
# 29.732137494637012
# [(234, 102), (-67, 279), (384, 65), (748, 330)]
# 28.460498941515414
# [(234, 103), (-66, 280), (385, 62), (751, 323)]
# 29.410882339705484
# [(237, 101), (-60, 283), (384, 61), (752, 319)]
# 30.675723300355934
# [(242, 97), (-51, 287), (383, 64), (750, 325)]
# 32.31098884280702
# [(239, 99), (-57, 284), (380, 63), (751, 318)]
# 30.364452901377952
# [(239, 99), (-57, 284), (382, 69), (746, 333)]
# 27.85677655436824
# [(239, 100), (-57, 285), (381, 66), (749, 324)]
# 28.792360097775937
# [(239, 99), (-57, 284), (385, 64), (749, 329)]
# 31.38470965295043
# [(240, 99), (-54, 287), (380, 66), (749, 324)]
# 29.732137494637012
# [(238, 99), (-58, 284), (383, 62), (752, 320)]
# 31.622776601683793
# [(238, 98), (-58, 284), (371, 65), (753, 304)]
# 29.274562336608895
# [(234, 105), (-68, 280), (387, 64), (749, 331)]
# 27.85677655436824
# [(238, 105), (-61, 285), (384, 65), (748, 330)]
# 27.313000567495326
# [(237, 107), (-63, 285), (384, 66), (748, 330)]
# 26.0
# [(240, 94), (-53, 285), (383, 68), (747, 332)]
# 31.016124838541646
# [(240, 101), (-56, 287), (382, 69), (746, 333)]
# 27.313000567495326
# [(238, 102), (-59, 285), (380, 66), (749, 324)]
# 27.51363298439521
# [(239, 99), (-57, 284), (383, 63), (751, 321)]
# 31.016124838541646
# [(235, 107), (-67, 282), (381, 64), (750, 322)]
# 26.248809496813376
# [(235, 107), (-67, 282), (387, 67), (746, 338)]
# 25.495097567963924
# [(227, 100), (-78, 270), (383, 68), (747, 332)]
# 26.476404589747453
# [(233, 100), (-68, 278), (383, 68), (747, 332)]
# 27.202941017470888
# [(232, 102), (-70, 277), (384, 66), (748, 331)]
# 27.202941017470888
# [(230, 99), (-72, 274), (381, 67), (747, 329)]
# 27.459060435491963
# [(236, 95), (-60, 280), (388, 68), (745, 342)]
# 31.38470965295043
# [(233, 97), (-66, 277), (383, 69), (745, 337)]
# 28.160255680657446
# [(235, 94), (-60, 279), (383, 68), (747, 332)]
# 30.364452901377952
# [(232, 96), (-67, 276), (389, 65), (748, 336)]
# 31.622776601683793
# [(235, 93), (-61, 278), (384, 70), (744, 341)]
# 30.364452901377952
# [(230, 98), (-72, 273), (374, 70), (747, 322)]
# 26.076809620810597
# [(229, 104), (-76, 274), (383, 73), (742, 344)]
# 22.80350850198276
# [(230, 95), (-71, 273), (383, 72), (742, 343)]
# 27.65863337187866
# [(231, 94), (-68, 274), (398, 69), (743, 358)]
# 32.202484376209235
# [(233, 93), (-65, 276), (398, 72), (740, 364)]
# 31.76476034853718
# [(234, 91), (-62, 277), (397, 70), (742, 359)]
# 33.54101966249684
# [(233, 97), (-66, 277), (394, 72), (741, 358)]
# 29.068883707497267
# [(229, 97), (-73, 272), (392, 71), (742, 354)]
# 27.85677655436824
# [(226, 109), (-84, 271), (394, 69), (743, 352)]
# 23.259406699226016
# [(226, 109), (-84, 271), (392, 71), (741, 355)]
# 21.93171219946131
# [(226, 109), (-84, 271), (393, 72), (740, 359)]
# 21.93171219946131
# [(221, 97), (-87, 262), (393, 70), (743, 353)]
# 27.892651361962706
# [(228, 95), (-74, 270), (392, 71), (742, 354)]
# 28.792360097775937
# [(227, 93), (-75, 268), (391, 70), (743, 350)]
# 30.364452901377952
# [(229, 94), (-71, 272), (387, 69), (744, 343)]
# 30.083217912982647
# [(228, 96), (-74, 271), (387, 72), (741, 349)]
# 26.92582403567252
# [(231, 94), (-68, 274), (384, 71), (743, 342)]
# 28.861739379323623
# [(232, 93), (-65, 275), (388, 71), (743, 348)]
# 29.732137494637012
# [(230, 95), (-71, 273), (386, 73), (741, 350)]
# 27.202941017470888
# [(229, 97), (-73, 272), (386, 69), (745, 340)]
# 27.892651361962706
# [(227, 98), (-76, 270), (387, 72), (741, 349)]
# 25.96150997149434
# [(226, 99), (-79, 269), (386, 71), (743, 344)]
# 25.709920264364882
# [(226, 99), (-79, 269), (388, 74), (740, 354)]
# 25.0
# [(220, 113), (-95, 263), (386, 73), (741, 350)]
# 17.26267650163207
# [(222, 113), (-92, 266), (389, 69), (744, 346)]
# 19.6468827043885
# [(229, 97), (-73, 272), (388, 71), (743, 348)]
# 27.202941017470888
# [(233, 90), (-63, 275), (389, 74), (739, 358)]
# 30.083217912982647
# [(229, 104), (-76, 274), (387, 72), (741, 349)]
# 23.40939982143925
# [(228, 105), (-79, 272), (387, 72), (741, 349)]
# 23.08679276123039
# [(232, 95), (-67, 275), (390, 73), (740, 356)]
# 28.231188426986208
# [(229, 97), (-73, 272), (387, 77), (737, 360)]
# 24.351591323771842
# [(229, 97), (-73, 272), (387, 72), (742, 349)]
# 27.202941017470888
# [(229, 97), (-73, 272), (387, 72), (742, 349)]
# 27.202941017470888
# [(232, 95), (-67, 276), (388, 71), (743, 348)]
# 28.792360097775937
# [(229, 94), (-71, 272), (388, 71), (743, 348)]
# 29.120439557122072
# [(231, 97), (-70, 274), (388, 73), (740, 354)]
# 26.570660511172846
# [(229, 96), (-73, 271), (387, 67), (746, 338)]
# 30.083217912982647
# [(231, 94), (-68, 274), (389, 69), (744, 346)]
# 30.675723300355934
# [(232, 93), (-65, 275), (386, 73), (741, 350)]
# 28.460498941515414
# [(232, 95), (-67, 276), (386, 71), (743, 344)]
# 28.460498941515414
# [(233, 94), (-64, 277), (386, 68), (746, 338)]
# 30.364452901377952
# [(233, 93), (-65, 276), (388, 70), (743, 347)]
# 30.675723300355934
# [(231, 96), (-70, 274), (385, 70), (744, 340)]
# 28.160255680657446
# [(229, 103), (-76, 273), (384, 68), (746, 336)]
# 25.709920264364882
# [(225, 104), (-83, 268), (385, 67), (747, 335)]
# 25.495097567963924
# [(229, 103), (-76, 273), (384, 68), (746, 336)]
# 25.709920264364882
# [(228, 103), (-77, 273), (388, 66), (747, 336)]
# 27.202941017470888
# [(232, 103), (-70, 278), (386, 68), (745, 339)]
# 26.570660511172846
# [(232, 98), (-69, 275), (386, 66), (748, 333)]
# 29.410882339705484
# [(232, 102), (-70, 277), (387, 72), (742, 349)]
# 24.698178070456937
# [(231, 104), (-72, 277), (389, 67), (746, 341)]
# 26.92582403567252
# [(239, 92), (-54, 283), (387, 67), (746, 338)]
# 33.61547262794322
# [(239, 92), (-54, 283), (385, 67), (747, 334)]
# 33.24154027718932
# [(231, 93), (-68, 273), (389, 69), (744, 346)]
# 30.675723300355934
# [(225, 97), (-80, 267), (391, 67), (746, 344)]
# 29.120439557122072
# [(231, 93), (-68, 273), (387, 67), (746, 338)]
# 31.32091952673165
# [(231, 93), (-68, 273), (386, 64), (750, 328)]
# 32.984845004941285
# [(232, 95), (-67, 276), (384, 65), (748, 330)]
# 31.04834939252005
# [(235, 93), (-61, 278), (384, 70), (744, 341)]
# 30.364452901377952
# [(232, 95), (-67, 276), (386, 68), (746, 339)]
# 30.364452901377952
# [(235, 93), (-61, 278), (384, 71), (743, 342)]
# 29.410882339705484
# [(234, 92), (-62, 277), (388, 71), (743, 348)]
# 31.016124838541646
# [(232, 95), (-67, 276), (384, 66), (748, 331)]
# 31.04834939252005
# [(234, 95), (-64, 278), (388, 66), (747, 336)]
# 31.953090617340916
# [(229, 98), (-73, 273), (384, 70), (744, 341)]
# 26.68332812825267
# [(229, 98), (-73, 273), (383, 68), (747, 332)]
# 27.65863337187866
# [(233, 96), (-66, 277), (384, 71), (743, 342)]
# 28.160255680657446
# [(228, 106), (-78, 273), (387, 67), (746, 338)]
# 25.0
# [(233, 96), (-66, 277), (383, 70), (745, 337)]
# 28.160255680657446
# [(231, 107), (-75, 277), (384, 71), (743, 342)]
# 22.135943621178654
# [(233, 94), (-64, 277), (382, 69), (746, 333)]
# 29.832867780352597
# [(233, 91), (-62, 276), (381, 69), (745, 334)]
# 30.805843601498726
# [(230, 96), (-70, 273), (387, 69), (744, 343)]
# 29.120439557122072
# [(219, 100), (-92, 259), (385, 70), (744, 340)]
# 25.079872407968907
# [(219, 100), (-92, 259), (386, 71), (743, 344)]
# 25.079872407968907
# [(231, 93), (-68, 273), (384, 71), (743, 342)]
# 28.861739379323623
# [(235, 93), (-61, 278), (387, 72), (742, 349)]
# 30.083217912982647
# [(231, 97), (-70, 274), (382, 71), (744, 339)]
# 26.68332812825267
# [(232, 95), (-67, 275), (384, 70), (744, 341)]
# 29.120439557122072
# [(234, 92), (-62, 278), (387, 70), (744, 344)]
# 30.675723300355934
# [(235, 93), (-61, 278), (382, 69), (746, 333)]
# 30.083217912982647
# [(235, 93), (-61, 278), (387, 72), (741, 349)]
# 30.083217912982647
# [(236, 92), (-58, 280), (383, 69), (745, 337)]
# 31.32091952673165
# [(236, 95), (-60, 280), (379, 73), (743, 337)]
# 26.92582403567252
# [(231, 100), (-71, 275), (377, 70), (746, 328)]
# 25.317977802344327
# [(230, 103), (-73, 275), (381, 72), (743, 340)]
# 23.53720459187964
# [(237, 89), (-56, 280), (378, 73), (743, 338)]
# 29.832867780352597
# [(232, 102), (-70, 277), (381, 72), (743, 340)]
# 23.769728648009426
# [(235, 93), (-61, 278), (378, 74), (742, 339)]
# 27.65863337187866
# [(234, 92), (-62, 278), (378, 74), (742, 339)]
# 27.65863337187866
# [(235, 87), (-57, 278), (380, 71), (744, 335)]
# 31.78049716414141
# [(234, 89), (-60, 277), (378, 73), (743, 338)]
# 29.614185789921695
# [(231, 94), (-68, 274), (382, 69), (746, 333)]
# 29.614185789921695
# [(231, 93), (-68, 273), (377, 75), (741, 339)]
# 26.30589287593181
# [(231, 93), (-68, 273), (381, 71), (745, 335)]
# 28.635642126552707
# [(226, 93), (-76, 268), (381, 71), (745, 335)]
# 28.160255680657446
# [(223, 94), (-82, 264), (377, 71), (745, 329)]
# 28.0
# [(227, 94), (-75, 269), (380, 73), (742, 341)]
# 27.16615541441225
# [(227, 94), (-75, 269), (383, 68), (747, 332)]
# 29.427877939124322
# [(228, 93), (-72, 270), (383, 70), (744, 338)]
# 29.427877939124322
# [(230, 92), (-69, 272), (383, 73), (742, 344)]
# 28.635642126552707
# [(230, 91), (-69, 271), (382, 69), (746, 333)]
# 30.59411708155671
# [(230, 92), (-69, 272), (382, 71), (744, 339)]
# 29.614185789921695
# [(228, 95), (-74, 270), (383, 73), (742, 344)]
# 26.476404589747453
# [(229, 94), (-72, 271), (380, 77), (739, 348)]
# 25.317977802344327
# [(228, 93), (-72, 270), (381, 69), (745, 334)]
# 29.274562336608895
# [(225, 98), (-80, 267), (384, 71), (743, 342)]
# 26.30589287593181
# [(223, 104), (-86, 266), (383, 72), (743, 343)]
# 22.20360331117452
# [(224, 103), (-84, 267), (383, 70), (745, 337)]
# 24.186773244895647
# [(230, 89), (-67, 272), (380, 72), (744, 336)]
# 30.4138126514911
# [(231, 90), (-67, 273), (383, 70), (745, 337)]
# 30.805843601498726
# [(230, 98), (-72, 273), (383, 72), (743, 343)]
# 25.709920264364882
# [(229, 97), (-73, 272), (381, 75), (740, 346)]
# 24.515301344262525
# [(231, 90), (-67, 273), (380, 72), (744, 336)]
# 29.427877939124322
# [(223, 93), (-82, 263), (380, 76), (740, 347)]
# 26.019223662515376
# [(220, 94), (-88, 259), (384, 71), (743, 342)]
# 28.071337695236398
# [(224, 95), (-81, 264), (381, 70), (745, 335)]
# 28.071337695236398
# [(228, 92), (-72, 270), (382, 74), (741, 344)]
# 27.459060435491963
# [(232, 92), (-66, 275), (384, 70), (744, 341)]
# 30.083217912982647
# [(230, 91), (-69, 271), (380, 71), (744, 336)]
# 29.427877939124322
# [(227, 94), (-75, 269), (382, 69), (746, 333)]
# 29.274562336608895
# [(228, 93), (-72, 270), (381, 70), (745, 335)]
# 29.274562336608895
# [(230, 91), (-69, 271), (381, 70), (745, 334)]
# 30.4138126514911
# [(231, 90), (-67, 272), (380, 71), (744, 335)]
# 30.4138126514911
# [(228, 95), (-74, 270), (381, 75), (740, 346)]
# 25.317977802344327
# [(228, 96), (-74, 271), (387, 72), (741, 349)]
# 26.92582403567252
# [(227, 93), (-75, 268), (381, 77), (738, 351)]
# 25.317977802344327
# [(224, 99), (-82, 266), (387, 72), (742, 349)]
# 25.495097567963924
# [(226, 99), (-79, 269), (390, 74), (740, 357)]
# 25.298221281347036
# [(229, 97), (-73, 272), (386, 73), (741, 350)]
# 25.96150997149434
# [(231, 93), (-68, 273), (386, 74), (740, 351)]
# 28.160255680657446
# [(228, 102), (-77, 271), (388, 76), (738, 359)]
# 22.47220505424423
# [(230, 92), (-69, 273), (383, 73), (742, 344)]
# 28.635642126552707
# [(229, 98), (-73, 273), (387, 72), (742, 349)]
# 26.248809496813376
# [(226, 106), (-82, 270), (387, 72), (741, 349)]
# 21.840329667841555
# [(226, 106), (-82, 270), (385, 70), (744, 340)]
# 22.561028345356956
# [(223, 99), (-85, 264), (388, 68), (745, 342)]
# 27.459060435491963
# [(223, 94), (-82, 264), (391, 67), (746, 344)]
# 30.805843601498726
# [(227, 93), (-75, 268), (389, 65), (748, 336)]
# 32.01562118716424
# [(229, 93), (-72, 271), (389, 69), (744, 346)]
# 30.364452901377952
# [(230, 91), (-69, 271), (387, 67), (746, 338)]
# 32.01562118716424
# [(231, 93), (-68, 273), (387, 72), (741, 349)]
# 29.410882339705484
# [(228, 96), (-74, 271), (387, 72), (742, 349)]
# 26.92582403567252
# [(231, 93), (-68, 274), (389, 69), (744, 346)]
# 30.675723300355934
# [(231, 94), (-68, 274), (383, 72), (743, 343)]
# 27.892651361962706
# [(234, 91), (-62, 277), (387, 69), (744, 343)]
# 31.622776601683793
# [(232, 95), (-67, 276), (385, 67), (747, 335)]
# 30.083217912982647
# [(231, 93), (-68, 273), (383, 67), (747, 332)]
# 30.805843601498726
# [(229, 97), (-73, 272), (383, 69), (745, 337)]
# 27.65863337187866
# [(231, 97), (-70, 275), (384, 71), (743, 342)]
# 26.92582403567252
# [(235, 87), (-57, 278), (377, 71), (745, 329)]
# 31.575306807693888
# [(232, 99), (-68, 277), (383, 72), (743, 342)]
# 25.96150997149434
# [(236, 88), (-57, 279), (387, 67), (746, 338)]
# 34.785054261852174
# [(235, 93), (-61, 278), (376, 72), (744, 331)]
# 28.442925306655784
# [(234, 95), (-63, 278), (381, 72), (743, 340)]
# 27.892651361962706
# [(234, 95), (-63, 278), (383, 70), (744, 338)]
# 29.120439557122072
# [(234, 95), (-63, 278), (383, 68), (747, 332)]
# 30.083217912982647
# [(234, 95), (-63, 278), (390, 69), (744, 346)]
# 30.463092423455635
# [(237, 90), (-56, 280), (383, 67), (747, 331)]
# 33.52610922848042
# [(230, 99), (-72, 274), (383, 68), (747, 332)]
# 27.65863337187866
# [(232, 95), (-67, 276), (385, 70), (744, 340)]
# 29.120439557122072
# [(234, 95), (-64, 278), (385, 67), (746, 335)]
# 30.364452901377952
# [(235, 94), (-60, 279), (387, 66), (747, 337)]
# 31.953090617340916
# [(237, 91), (-55, 281), (379, 68), (747, 326)]
# 32.01562118716424
# [(236, 92), (-58, 280), (380, 67), (748, 325)]
# 32.01562118716424
# [(235, 94), (-60, 279), (381, 65), (749, 323)]
# 32.01562118716424
# [(235, 94), (-60, 279), (380, 66), (749, 324)]
# 30.805843601498726
# [(233, 97), (-66, 277), (383, 67), (747, 332)]
# 29.120439557122072
# [(235, 91), (-59, 279), (384, 66), (748, 331)]
# 33.24154027718932
# [(237, 84), (-52, 280), (388, 66), (747, 337)]
# 37.0
# [(238, 86), (-51, 281), (390, 66), (747, 340)]
# 36.76955262170047
# [(236, 96), (-59, 281), (394, 63), (749, 340)]
# 34.438350715445125
# [(237, 99), (-61, 282), (390, 68), (745, 345)]
# 29.966648127543394
# [(236, 102), (-63, 282), (384, 63), (750, 324)]
# 29.732137494637012
# [(232, 106), (-71, 279), (388, 66), (747, 336)]
# 26.0
# [(232, 106), (-71, 279), (387, 66), (747, 337)]
# 25.632011235952593
# [(232, 106), (-71, 279), (385, 64), (749, 329)]
# 26.248809496813376
# [(227, 100), (-78, 270), (386, 63), (750, 327)]
# 29.614185789921695
# [(225, 103), (-83, 268), (384, 65), (748, 330)]
# 26.30589287593181
# [(232, 103), (-70, 278), (387, 61), (751, 326)]
# 29.410882339705484
# [(235, 97), (-62, 280), (383, 62), (752, 320)]
# 32.28002478313795
# [(230, 106), (-75, 276), (389, 64), (748, 335)]
# 26.570660511172846
# [(232, 103), (-70, 278), (382, 63), (751, 322)]
# 27.892651361962706
# [(239, 99), (-57, 284), (393, 61), (750, 335)]
# 34.0
# [(237, 97), (-58, 283), (397, 64), (747, 348)]
# 34.48187929913333
# [(236, 101), (-63, 282), (393, 61), (750, 335)]
# 32.202484376209235
# [(239, 100), (-57, 285), (394, 61), (751, 335)]
# 34.0
# [(234, 106), (-68, 281), (390, 57), (754, 322)]
# 31.38470965295043
# [(237, 101), (-60, 283), (383, 59), (754, 314)]
# 31.622776601683793
# [(235, 107), (-67, 282), (385, 59), (753, 317)]
# 28.792360097775937
# [(236, 110), (-66, 285), (383, 61), (752, 320)]
# 26.570660511172846
# [(238, 112), (-64, 287), (390, 57), (754, 322)]
# 29.5296461204668
# [(247, 91), (-39, 292), (385, 59), (754, 317)]
# 38.48376280978771
# [(244, 101), (-49, 291), (391, 56), (755, 321)]
# 36.235341863986875
# [(245, 99), (-45, 293), (391, 57), (755, 321)]
# 36.71511950137164
# [(164, 208), (-184, 232), (388, 58), (754, 320)]
# 33.24154027718932
# [(164, 208), (-184, 232), (392, 60), (752, 331)]
# 32.55764119219941
# [(238, 106), (-61, 286), (392, 61), (751, 332)]
# 30.886890422961002
# [(242, 104), (-54, 290), (387, 57), (755, 315)]
# 33.1058907144937
# [(242, 101), (-52, 290), (391, 58), (753, 326)]
# 34.88552708502482
# [(243, 100), (-49, 290), (388, 60), (752, 325)]
# 33.54101966249684
# [(245, 99), (-46, 292), (391, 58), (753, 326)]
# 36.71511950137164
# [(243, 100), (-49, 290), (395, 62), (749, 339)]
# 34.66987164671943
# [(243, 102), (-52, 290), (388, 58), (754, 319)]
# 33.54101966249684
# [(241, 103), (-55, 288), (389, 58), (753, 323)]
# 33.54101966249684
# [(243, 100), (-49, 290), (391, 56), (755, 321)]
# 36.235341863986875
# [(245, 96), (-44, 292), (388, 60), (752, 325)]
# 35.77708763999664
# [(245, 102), (-47, 293), (393, 59), (752, 330)]
# 35.510561809129406
# [(242, 101), (-52, 289), (390, 62), (750, 333)]
# 33.12099032335839
# [(237, 111), (-65, 286), (392, 60), (751, 331)]
# 28.653097563788805
# [(234, 121), (-74, 285), (393, 59), (752, 330)]
# 23.853720883753127
# [(247, 92), (-39, 292), (385, 59), (754, 317)]
# 38.48376280978771
# [(246, 93), (-41, 292), (388, 61), (752, 325)]
# 37.12142238654117
# [(245, 95), (-45, 290), (389, 64), (749, 335)]
# 35.35533905932738
# [(246, 100), (-45, 293), (385, 59), (753, 317)]
# 34.438350715445125
# [(241, 102), (-55, 288), (390, 63), (749, 334)]
# 31.76476034853718
# [(241, 102), (-55, 288), (388, 66), (747, 336)]
# 29.5296461204668
# [(241, 102), (-55, 288), (383, 62), (751, 320)]
# 30.463092423455635
# [(240, 99), (-54, 287), (389, 64), (748, 335)]
# 32.202484376209235
# [(242, 98), (-50, 289), (391, 67), (746, 344)]
# 32.2490309931942
# [(239, 100), (-57, 285), (383, 62), (752, 320)]
# 31.016124838541646
# [(244, 94), (-45, 290), (379, 63), (752, 314)]
# 33.83784863137726
# [(239, 100), (-57, 285), (383, 68), (747, 332)]
# 28.231188426986208
# [(242, 97), (-51, 288), (379, 66), (749, 321)]
# 30.675723300355934
# [(244, 94), (-45, 290), (386, 63), (750, 327)]
# 35.34119409414458
# [(242, 97), (-51, 288), (381, 66), (749, 324)]
# 31.016124838541646
# [(241, 96), (-51, 287), (377, 65), (751, 317)]
# 31.32091952673165
# [(240, 97), (-55, 285), (377, 71), (745, 329)]
# 27.202941017470888
# [(240, 94), (-53, 285), (379, 68), (748, 326)]
# 30.364452901377952
# [(243, 90), (-44, 288), (377, 70), (746, 328)]
# 31.622776601683793
# [(242, 97), (-51, 288), (383, 68), (747, 332)]
# 30.463092423455635
# [(241, 96), (-51, 287), (377, 66), (750, 318)]
# 30.364452901377952
# [(239, 99), (-57, 284), (377, 71), (745, 329)]
# 26.248809496813376
# [(241, 96), (-52, 286), (379, 70), (746, 331)]
# 28.792360097775937
# [(239, 93), (-53, 284), (379, 68), (748, 326)]
# 31.32091952673165
# [(239, 93), (-53, 284), (385, 70), (744, 340)]
# 31.38470965295043
# [(229, 97), (-73, 272), (384, 66), (748, 330)]
# 29.614185789921695
# [(235, 93), (-61, 278), (379, 68), (747, 326)]
# 30.805843601498726
# [(233, 97), (-66, 277), (378, 67), (749, 322)]
# 28.442925306655784
# [(234, 95), (-63, 278), (378, 69), (747, 327)]
# 28.635642126552707
# [(236, 94), (-60, 280), (378, 64), (751, 316)]
# 31.78049716414141
# [(238, 91), (-54, 282), (376, 67), (749, 318)]
# 31.78049716414141
# [(236, 96), (-59, 281), (374, 65), (752, 310)]
# 30.4138126514911
# [(238, 92), (-54, 282), (377, 65), (751, 317)]
# 32.7566787083184
# [(238, 91), (-54, 282), (371, 70), (749, 315)]
# 30.265491900843113
# [(238, 92), (-54, 282), (376, 67), (749, 318)]
# 31.78049716414141
# [(237, 93), (-57, 281), (373, 67), (750, 312)]
# 30.4138126514911
# [(236, 95), (-60, 280), (376, 68), (749, 319)]
# 29.614185789921695
# [(233, 97), (-66, 277), (376, 68), (749, 319)]
# 28.284271247461902
# [(240, 87), (-50, 283), (379, 63), (752, 315)]
# 36.138621999185304
# [(239, 89), (-52, 283), (378, 67), (749, 322)]
# 32.984845004941285
# [(236, 98), (-61, 281), (381, 64), (750, 322)]
# 30.083217912982647
# [(239, 93), (-53, 284), (387, 67), (746, 338)]
# 32.69556544854363
# [(240, 88), (-49, 284), (379, 68), (747, 326)]
# 33.24154027718932

# %%
# Steve Mitchell
# June 2017

import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import argparse
import cv2
import imutils
import time

# preliminary attempt at lane following system
# largely derived from: https://medium.com/pharos-production/
# road-lane-recognition-with-opencv-and-ios-a892a3ab635c

# identify filename of video to be analyzed
cap = cv2.VideoCapture('lane_juniors.mp4')
i_=0

# loop through until entire video file is played
while(cap.isOpened()):
    

    # read video frame & show on screen
    ret, frame = cap.read()
    
    
    if ret ==False:
        break
    i_=i_+1;
    
    # cv2.imshow("Original Scene", frame)
    
    
   
    
    
    
    
    

    # snip section of video frame of interest & show on screen
    snip = frame[1250:2160,400:3200]
    snip=cv2.resize(snip,(300,900))
    
    
    
    
    
    
    
    
    
    
    
    
    
    cv2.imshow("Snip",snip)

    # create polygon (trapezoid) mask to select region of interest
    mask = np.zeros((snip.shape[0], snip.shape[1]), dtype="uint8")
    pts = np.array([[100,150],[0,900],[300,900],[250,150]],dtype=np.int32)
    cv2.fillConvexPoly(mask, pts, 255)
    cv2.imshow("Mask", mask)

    # apply mask and show masked image on screen
    masked = cv2.bitwise_and(snip, snip, mask=mask)
    cv2.imshow("Region of Interest", masked)

    # convert to grayscale then black/white to binary image
    frame = cv2.cvtColor(masked, cv2.COLOR_BGR2GRAY)
    thresh = 170
    frame = cv2.threshold(frame, thresh, 255, cv2.THRESH_BINARY)[1]
    cv2.imshow("Black/White", frame)

    # blur image to help with edge detection
    blurred = cv2.GaussianBlur(frame, (11, 11), 0)
    # cv2.imshow("Blurred", blurred)

    # identify edges & show on screen
    edged = cv2.Canny(blurred, 50, 150)
    cv2.imshow("Edged", edged)

    # perform full Hough Transform to identify lane lines
    lines = cv2.HoughLines(edged, 1, np.pi / 180, 25)
   
   
    

    # define arrays for left and right lanes
    rho_left = []
    theta_left = []
    rho_right = []
    theta_right = []

    # ensure cv2.HoughLines found at least one line
    if lines is not None:
 
        # loop through all of the lines found by cv2.HoughLines
        for i in range(0, len(lines)):

            # evaluate each row of cv2.HoughLines output 'lines'
            for rho, theta in lines[i]:

                # collect left lanes
                if theta <np.pi/4:
                    
                    rho_left.append(rho)
                    theta_left.append(theta)

                    # # plot all lane lines for DEMO PURPOSES ONLY
                    # a = np.cos(theta); b = np.sin(theta)
                    # x0 = a * rho; y0 = b * rho
                    # x1 = int(x0 + 400 * (-b)); y1 = int(y0 + 400 * (a))
                    # x2 = int(x0 - 600 * (-b)); y2 = int(y0 - 600 * (a))
                    #
                    # cv2.line(snip, (x1, y1), (x2, y2), (0, 0, 255), 1)

                # collect right lanes
                if theta > 3*np.pi/4 and theta < np.pi:
                    
                    rho_right.append(rho)
                    theta_right.append(theta)

                    # # plot all lane lines for DEMO PURPOSES ONLY
                    # a = np.cos(theta); b = np.sin(theta)
                    # x0 = a * rho; y0 = b * rho
                    # x1 = int(x0 + 400 * (-b)); y1 = int(y0 + 400 * (a))
                    
                    # x2 = int(x0 - 600 * (-b)); y2 = int(y0 - 600 * (a))
                    #
                    # cv2.line(snip, (x1, y1), (x2, y2), (0, 0, 255), 1)

    # statistics to identify median lane dimensions
    left_rho = np.median(rho_left)
    left_theta = np.median(theta_left)
    right_rho = np.median(rho_right)
    right_theta = np.median(theta_right)
    
    
    
    

    # plot median lane on top of scene snip
    if left_theta < np.pi/4:
        
        a = np.cos(left_theta); b = np.sin(left_theta)
        x0 = a * left_rho; y0 = b * left_rho
        offset1 = -200; offset2 = 550
        x1 = int(x0 - offset1 * (-b)); y1 = int(y0 - offset1 * (a))
        x2 = int(x0 + offset2 * (-b)); y2 = int(y0 + offset2 * (a))

        cv2.line(snip, (x1, y1), (x2, y2), (255, 255, 0), 3)
        

    if right_theta > 3*np.pi/4 and theta<np.pi:
        
        a = np.cos(right_theta); b = np.sin(right_theta)
        x0 = a * right_rho; y0 = b * right_rho
        offset1 = 250; offset2 = 500
        x3 = int(x0 - offset1 * (-b)); y3 = int(y0 - offset1 * (a))
        x4 = int(x0 - offset2 * (-b)); y4 = int(y0 - offset2 * (a))
        

        cv2.line(snip, (x3, y3), (x4, y4), (255, 0, 0), 3)
    
    
    
        
   
    
    
    
    
            
    
    



    # overlay semi-transparent lane outline on original
    if left_theta < np.pi/4 and right_theta < np.pi and right_theta>3*np.pi/4:
        pts = np.array([[x1,y1], [x2, y2], [x4, y4], [x3,y3]], dtype=np.int32)
        

        # (1) create a copy of the original:
        overlay = snip.copy()
        # (2) draw shapes:
        cv2.fillConvexPoly(overlay, pts, (255, 255, 0))
        cv2.imshow('overlay',overlay)
        # (3) blend with the original:
        opacity = 0.4
        cv2.addWeighted(overlay, opacity, snip, 1 - opacity, 0, snip)

    cv2.imshow("Lined", snip)
    x1_=int ((x1+x3)/2)
    y1_=int ((y1+y3)/2)
    
    x2_=int ((x2+x4)/2)
    y2_=int ((y2+y4)/2)
    
    cv2.line( snip ,(x1_,y1_),(x2_,y2_),(255,255,255),2)
    
    cv2.imshow('deviation',snip)
    
    deviation =np.sqrt(np.square(x1_ - (snip.shape[1]/2)) + np.square (y1_ - (snip.shape[0]/2)))
    print(deviation)
    
    


    # perform probablistic Hough Transform to identify lane lines
    # lines = cv2.HoughLinesP(edged, 1, np.pi / 180, 20, 2, 1)
    # for x in range(0, len(lines)):
    #     for x1, y1, x2, y2 in lines[x]:
    #         cv2.line(snip, (x1, y1), (x2, y2), (0, 0, 255), 2)


    # press the q key to break out of video
    if cv2.waitKey(25) & 0xFF == ord('q'):
        break 

# clear everything once finished
cap.release()

cv2.destroyAllWindows()
# Out:
# 229.05457864884517
# 229.0
# 228.00877176108818
# 228.0021929719098
# 227.0
# 228.0021929719098
# 228.0021929719098
# 230.0021739027699
# 231.00216449202375
# 230.0021739027699
# 226.00221237855172
# 229.0087334579186
# 229.0
# 229.0349318335524
# 229.05457864884517
# 230.0
# 230.0021739027699
# 229.0087334579186
# 228.07893370497854
# 229.05457864884517
# 229.0087334579186
# 228.0548179714693
# 229.01964981197574
# 228.01973598791838
# 230.0021739027699
# 231.00865784641059
# 228.01973598791838
# 230.0021739027699
# 229.0087334579186
# 230.00869548780108
# 230.00869548780108
# 231.00216449202375
# 231.00216449202375
# 230.00869548780108
# 230.0021739027699
# 232.0021551624036
# 228.01973598791838
# 230.0
# 230.0195643852931
# 230.00869548780108
# 232.01939574095957
# 230.05434140654683
# 231.05410621756974
# 229.13969538253298
# 230.0347799790284
# 228.0350850198276
# 228.01973598791838
# 231.03462943896528
# 228.0350850198276
# 229.01964981197574
# 227.00881040171106
# 227.05505940189926
# 230.0347799790284
# 230.0195643852931
# 230.00869548780108
# 230.00869548780108
# 231.07790893982056
# 230.0347799790284
# 233.01931250435015
# 230.05434140654683
# 230.17601960239037
# 230.0347799790284
# 232.0021551624036
# 231.07790893982056
# 229.0785891348207
# 230.0347799790284
# 231.05410621756974
# 231.05410621756974
# 229.01964981197574
# 230.07824755939012
# 230.05434140654683
# 232.0538730553748
# 230.07824755939012
# 231.07790893982056
# 229.0785891348207
# 229.13969538253298
# 231.03462943896528
# 232.01939574095957
# 231.03462943896528
# 229.2640399190418
# 230.13908837917995
# 231.10603626906848
# 231.00216449202375
# 231.07790893982056
# 232.1055794245369
# 229.17678765529462
# 231.07790893982056
# 232.17450333746814
# 230.21728866442677
# 230.07824755939012
# 232.07757323791543
# 231.05410621756974
# 230.10649708341572
# 230.0347799790284
# 231.07790893982056
# 229.0785891348207
# 231.10603626906848
# 230.10649708341572
# 234.00213674238105
# 231.10603626906848
# 231.21634890292685
# 230.2628932329306
# 231.42385356743154
# 230.4256930118688
# 229.2640399190418
# 231.1384866265244
# 229.17678765529462
# 229.17678765529462
# 229.21823662178366
# 231.10603626906848
# 228.1403077055872
# 231.1384866265244
# 228.07893370497854
# 231.21634890292685
# 230.05434140654683
# 231.05410621756974
# 230.0195643852931
# 230.07824755939012
# 232.1055794245369
# 231.10603626906848
# 229.05457864884517
# 232.13789005675054
# 231.1384866265244
# 228.1074308302998
# 229.0785891348207
# 229.0785891348207
# 227.14092541856036
# 229.05457864884517
# 230.13908837917995
# 230.13908837917995
# 228.1074308302998
# 230.10649708341572
# 231.07790893982056
# 227.17834403833479
# 230.17601960239037
# 229.17678765529462
# 230.05434140654683
# 229.0785891348207
# 230.21728866442677
# 231.17525819170183
# 229.13969538253298
# 231.21634890292685
# 229.10696191953662
# 229.17678765529462
# 232.13789005675054
# 229.17678765529462
# 231.1384866265244
# 231.21634890292685
# 229.21823662178366
# 229.13969538253298
# 231.21634890292685
# 230.10649708341572
# 229.31419493786248
# 228.26519664635694
# 232.13789005675054
# 231.1384866265244
# 233.05364189387817
# 232.13789005675054
# 234.05341270744162
# 233.10512649875378
# 233.05364189387817
# 231.17525819170183
# 233.0772404161333
# 232.2154172315008
# 232.2154172315008
# 229.42754847663784
# 229.36869882353173
# 229.63013739489858
# 229.63013739489858
# 229.63013739489858
# 231.5534495532295
# 229.55827146935917
# 230.70327262524907
# 232.2154172315008
# 232.26062946612367
# 231.3114783144148
# 232.26062946612367
# 230.3670983452281
# 232.42202993692314
# 230.4256930118688
# 230.3670983452281
# 233.173754955398
# 233.25951213187426
# 232.42202993692314
# 233.54871012274933
# 232.6972281742952
# 232.6972281742952
# 229.42754847663784
# 231.62469643800938
# 231.70023737579555
# 232.48440807933767
# 231.5534495532295
# 230.4256930118688
# 231.42385356743154
# 233.30880823492285
# 233.30880823492285
# 233.25951213187426
# 230.4256930118688
# 232.26062946612367
# 233.42022191746798
# 233.30880823492285
# 231.62469643800938
# 230.4886114323222
# 234.21357774475842
# 233.25951213187426
# 233.30880823492285
# 234.2584043316269
# 229.36869882353173
# 228.31557108528537
